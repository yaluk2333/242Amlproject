# %% [markdown]
# # Predicting New Song Popularity and Building a Recommendation System
# ### 242A final project
#
# **Team Members:** Hanning Lin, Yalu Kong, Junxing WU, Roxana Li, Jiuqiao Yu
# **Date:** [2025-12-14]

# %% [markdown]
# ## Part 1 Motivation

# %% [markdown]
# ## Part 2 Data & Learning Problem Dataset Description

# %% [markdown]
# ### Research Questions

# %% [markdown]
# ### Data introduction

# %% [markdown]
# ### Exploratory Data Analysis (EDA)

# %% [markdown]
# ## Part 3 Methodology Data Processing

# %% [markdown]
# ### Data Preprocessing

# %% [markdown]
# ### baseline model：

# %% [markdown]
# ### advanced model

# %% [markdown]
# ### Recommendation Model

# %% [markdown]
# ## Part 4 Result and discussion

# %% [markdown]
# ## Part 5 Conclusion & Future Work
